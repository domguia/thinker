# %% [markdown]
# # 🚀 Thinker: Autoresearch Experiment Loop
# Ce notebook est conçu pour être piloté par **Antigravity** via VS Code ou utilisé manuellement pour lancer des expériences sur le GPU de Colab.

# %% [markdown]
# ## 🛠️ Setup Environment

# %%
# Installation des dépendances nécessaires
# !pip install -q torchinfo lightning torchmetrics transformers accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 23.0 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 65.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 56.0 MB/s eta 0:00:00

# %%
# Récupération du code
import os
repo_name = 'thinker'
if not os.path.exists(repo_name):
    # !git clone https://github.com/domguia/thinker

# On s'assure d'être à la racine du projet (là où se trouve le dossier core/)
# Note: Ajuste le chemin si ton repo contient un sous-dossier éponyme
if os.path.exists(f'/content/{repo_name}/{repo_name}'):
    # %cd /content/{repo_name}/{repo_name}
else:
    # %cd /content/{repo_name}
# Out:
# Cloning into 'thinker'...
# remote: Enumerating objects: 492, done.
# remote: Counting objects: 100% (262/262), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 492 (delta 132), reused 205 (delta 77), pack-reused 230 (from 1)
# Receiving objects: 100% (492/492), 12.93 MiB | 19.30 MiB/s, done.
# Resolving deltas: 100% (245/245), done.
# /content/thinker

# %% [markdown]
# ## 🧪 Run Experiment
# Cette cellule lance l'entraînement avec le budget de temps défini dans `scripts/train.py`. On injecte le `PYTHONPATH` pour permettre les imports relatifs dans les sous-dossiers.

# %%
# Lancement de l'entraînement avec PYTHONPATH défini sur la racine du projet
# !export PYTHONPATH=:/home/djm/Workspaces/research/thinker && python -u scripts/train.py --exp_name EXP-002 2>&1 | tee run.log
# Out:
# Using device: cuda
# Total parameters: 42.8 K
# Starting training on cuda for a maximum of 15 minutes.
# Step     0 | Elapsed: 0.00m | Loss: 37.8503 | Acc: 0.0055 | n_latent: 7 | n_step: 1
# Step   100 | Elapsed: 0.09m | Loss: 7.8858 | Acc: 0.4666 | n_latent: 6 | n_step: 2
# Step   200 | Elapsed: 0.17m | Loss: 2.4185 | Acc: 0.5843 | n_latent: 8 | n_step: 1
# Step   300 | Elapsed: 0.23m | Loss: 2.1249 | Acc: 0.5960 | n_latent: 8 | n_step: 1
# Step   400 | Elapsed: 0.31m | Loss: 2.0221 | Acc: 0.6019 | n_latent: 8 | n_step: 3
# Step   500 | Elapsed: 0.39m | Loss: 2.0012 | Acc: 0.5977 | n_latent: 5 | n_step: 3
# Step   600 | Elapsed: 0.46m | Loss: 1.9924 | Acc: 0.5959 | n_latent: 6 | n_step: 3
# Step   700 | Elapsed: 0.55m | Loss: 1.9491 | Acc: 0.6009 | n_latent: 6 | n_step: 3
# Step   800 | Elapsed: 0.62m | Loss: 1.9283 | Acc: 0.6026 | n_latent: 5 | n_step: 3
# Step   900 | Elapsed: 0.69m | Loss: 1.9124 | Acc: 0.6041 | n_latent: 8 | n_step: 1
# ...

# %% [markdown]
# ## 📊 Results Summary

# %%
import pandas as pd
import os
if os.path.exists('results.tsv'):
    df = pd.read_csv('results.tsv', sep='\t')
    display(df.tail(10))
else:
    print("Aucun fichier results.tsv trouvé.")
